# %% [markdown]
# # ResNet35 Unet with SSIM Loss Function

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, UpSampling2D, Concatenate, Dense, BatchNormalization, Dropout, MaxPool2D as MaxPooling2D, Input, GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Activation, SpatialDropout2D
import six

# %%
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %% [markdown]
# ## ResNet34

# %%
def _bn_relu(input):
    """Helper to build a BN -> relu block
    """
    norm = BatchNormalization(axis=CHANNEL_AXIS)(input)
    return Activation("relu")(norm)


def _conv_bn_relu(**conv_params):
    """Helper to build a conv -> BN -> relu block
    """
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-4))

    def f(input):
        conv = Conv2D(filters=filters, kernel_size=kernel_size,
                      strides=strides, padding=padding,
                      kernel_initializer=kernel_initializer,
                      kernel_regularizer=kernel_regularizer)(input)
        return _bn_relu(conv)

    return f


def _bn_relu_conv(**conv_params):
    """Helper to build a BN -> relu -> conv block.
    This is an improved scheme proposed in http://arxiv.org/pdf/1603.05027v2.pdf
    """
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-4))

    def f(input):
        activation = _bn_relu(input)
        return Conv2D(filters=filters, kernel_size=kernel_size,
                      strides=strides, padding=padding,
                      kernel_initializer=kernel_initializer,
                      kernel_regularizer=kernel_regularizer)(activation)

    return f


def _shortcut(input, residual):
    """Adds a shortcut between input and residual block and merges them with "sum"
    """
    # Expand channels of shortcut to match residual.
    # Stride appropriately to match residual (width, height)
    # Should be int if network architecture is correctly configured.
    input_shape = K.int_shape(input)
    residual_shape = K.int_shape(residual)
    stride_width = int(round(input_shape[ROW_AXIS] / residual_shape[ROW_AXIS]))
    stride_height = int(round(input_shape[COL_AXIS] / residual_shape[COL_AXIS]))
    equal_channels = input_shape[CHANNEL_AXIS] == residual_shape[CHANNEL_AXIS]

    shortcut = input
#     print(stride_width, stride_height)
    # 1 X 1 conv if shape is different. Else identity.
    if stride_width > 1 or stride_height > 1 or not equal_channels:
        shortcut = Conv2D(filters=residual_shape[CHANNEL_AXIS],
                          kernel_size=(1, 1),
                          strides=(stride_width, stride_height),
                          padding="valid",
                          kernel_initializer="he_normal",
                          kernel_regularizer=l2(0.0001))(input)

    return add([shortcut, residual])


def _residual_block(block_function, filters, repetitions, is_first_layer=False):
    """Builds a residual block with repeating bottleneck blocks.
    """
    def f(input):
        for i in range(repetitions):
            init_strides = (1, 1)
            if i == 0 and not is_first_layer:
                init_strides = (2, 2)
            input = block_function(filters=filters, init_strides=init_strides,
                                   is_first_block_of_first_layer=(is_first_layer and i == 0))(input)
        return input

    return f


def basic_block(filters, init_strides=(1, 1), is_first_block_of_first_layer=False):
    """Basic 3 X 3 convolution blocks for use on resnets with layers <= 34.
    Follows improved proposed scheme in http://arxiv.org/pdf/1603.05027v2.pdf
    """
#     print(init_strides);
    def f(input):

        if is_first_block_of_first_layer:
            # don't repeat bn->relu since we just did bn->relu->maxpool
            conv1 = Conv2D(filters=filters, kernel_size=(3, 3),
                           strides=init_strides,
                           padding="same",
                           kernel_initializer="he_normal",
                           kernel_regularizer=l2(1e-4))(input)
        else:
            conv1 = _bn_relu_conv(filters=filters, kernel_size=(3, 3),
                                  strides=init_strides)(input)

        residual = _bn_relu_conv(filters=filters, kernel_size=(3, 3))(conv1)
        return _shortcut(input, residual)

    return f


def bottleneck(filters, init_strides=(1, 1), is_first_block_of_first_layer=False):
    """Bottleneck architecture for > 34 layer resnet.
    Follows improved proposed scheme in http://arxiv.org/pdf/1603.05027v2.pdf
    Returns:
        A final conv layer of filters * 4
    """
    def f(input):

        if is_first_block_of_first_layer:
            # don't repeat bn->relu since we just did bn->relu->maxpool
            conv_1_1 = Conv2D(filters=filters, kernel_size=(1, 1),
                              strides=init_strides,
                              padding="same",
                              kernel_initializer="he_normal",
                              kernel_regularizer=l2(1e-4))(input)
        else:
            conv_1_1 = _bn_relu_conv(filters=filters, kernel_size=(1, 1),
                                     strides=init_strides)(input)

        conv_3_3 = _bn_relu_conv(filters=filters, kernel_size=(3, 3))(conv_1_1)
        residual = _bn_relu_conv(filters=filters * 4, kernel_size=(1, 1))(conv_3_3)
        return _shortcut(input, residual)

    return f


def _handle_dim_ordering():
    global ROW_AXIS
    global COL_AXIS
    global CHANNEL_AXIS
    if K.image_data_format() == 'channels_last':
        ROW_AXIS = 1
        COL_AXIS = 2
        CHANNEL_AXIS = 3
    else:
        CHANNEL_AXIS = 1
        ROW_AXIS = 2
        COL_AXIS = 3


def _get_block(identifier):
    if isinstance(identifier, six.string_types):
        res = globals().get(identifier)
        if not res:
            raise ValueError('Invalid {}'.format(identifier))
        return res
    return identifier


class ResnetBuilder(object):
    @staticmethod
    def build(input_shape, block_fn, repetitions):
        """Builds a custom ResNet like architecture.
        Args:
            input_shape: The input shape in the form (nb_channels, nb_rows, nb_cols)
            num_outputs: The number of outputs at final softmax layer
            block_fn: The block function to use. This is either `basic_block` or `bottleneck`.
                The original paper used basic_block for layers < 50
            repetitions: Number of repetitions of various block units.
                At each block unit, the number of filters are doubled and the input size is halved
        Returns:
            The keras `Model`.
        """
        _handle_dim_ordering()
        if len(input_shape) != 3:
            raise Exception("Input shape should be a tuple (nb_channels, nb_rows, nb_cols)")

        # Permute dimension order if necessary
        if K.image_data_format() == 'channels_first':
            input_shape = (input_shape[1], input_shape[2], input_shape[0])

        # Load function from str if needed.
        block_fn = _get_block(block_fn)

        input = Input(shape=input_shape)
        conv1 = _conv_bn_relu(filters=64, kernel_size=(7, 7), strides=(2, 2))(input)
        pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(conv1)

        block = pool1
        filters = 64
        for i, r in enumerate(repetitions):
            block = _residual_block(block_fn, filters=filters, repetitions=r, is_first_layer=(i == 0))(block)
            filters *= 2

        # Last activation
        block = _bn_relu(block)

        model = Model(inputs=input, outputs=block)
        return model

    @staticmethod
    def build_resnet_18(input_shape):
        return ResnetBuilder.build(input_shape, basic_block, [2, 2, 2, 2])

    @staticmethod
    def build_resnet_34(input_shape):
        return ResnetBuilder.build(input_shape, basic_block, [3, 4, 6, 3])

# %% [markdown]
# ## Build UNet Model

# %%
# https://github.com/qubvel/segmentation_models/blob/master/segmentation_models/unet/models.py

def handle_block_names(stage):
    conv_name = 'decoder_stage{}_conv'.format(stage)
    bn_name = 'decoder_stage{}_bn'.format(stage)
    relu_name = 'decoder_stage{}_relu'.format(stage)
    up_name = 'decoder_stage{}_upsample'.format(stage)
    return conv_name, bn_name, relu_name, up_name


def Upsample2D_block(filters, stage, kernel_size=(3,3), upsample_rate=(2,2),
                     batchnorm=False, skip=None):

    def layer(input_tensor):

        conv_name, bn_name, relu_name, up_name = handle_block_names(stage)

        x = UpSampling2D(size=upsample_rate, name=up_name)(input_tensor)

        if skip is not None:
            x = Concatenate()([x, skip])

        x = Conv2D(filters, kernel_size, padding='same', name=conv_name+'1')(x)
        if batchnorm:
            x = BatchNormalization(name=bn_name+'1')(x)
        x = Activation('relu', name=relu_name+'1')(x)

        x = Conv2D(filters, kernel_size, padding='same', name=conv_name+'2')(x)
        if batchnorm:
            x = BatchNormalization(name=bn_name+'2')(x)
        x = Activation('relu', name=relu_name+'2')(x)

        return x
    return layer


def Transpose2D_block(filters, stage, kernel_size=(3,3), upsample_rate=(2,2),
                      transpose_kernel_size=(4,4), batchnorm=False, skip=None):

    def layer(input_tensor):

        conv_name, bn_name, relu_name, up_name = handle_block_names(stage)

        x = Conv2DTranspose(filters, transpose_kernel_size, strides=upsample_rate,
                            padding='same', name=up_name)(input_tensor)
        if batchnorm:
            x = BatchNormalization(name=bn_name+'1')(x)
        x = Activation('relu', name=relu_name+'1')(x)

        if skip is not None:
            x = Concatenate()([x, skip])

        x = Conv2D(filters, kernel_size, padding='same', name=conv_name+'2')(x)
        if batchnorm:
            x = BatchNormalization(name=bn_name+'2')(x)
        x = Activation('relu', name=relu_name+'2')(x)

        return x
    return layer

# %%
def build_unet(backbone, classes, last_block_filters, skip_layers,
               n_upsample_blocks=5, upsample_rates=(2,2,2,2,2),
               block_type='upsampling', activation='sigmoid', name='mymodel',
               **kwargs):

    input = backbone.input
    x = backbone.output

    if block_type == 'transpose':
        up_block = Transpose2D_block
    else:
        up_block = Upsample2D_block

    # convert layer names to indices
    skip_layers = ([get_layer_number(backbone, l) if isinstance(l, str) else l
                    for l in skip_layers])
#     print(skip_layers)
    for i in range(n_upsample_blocks):

        # check if there is a skip connection
        if i < len(skip_layers):
#             print(backbone.layers[skip_layers[i]])
#             print(backbone.layers[skip_layers[i]].output)
            skip = backbone.layers[skip_layers[i]].output
        else:
            skip = None

        up_size = (upsample_rates[i], upsample_rates[i])
        filters = last_block_filters * 2**(n_upsample_blocks-(i+1))
#         print(filters)

        x = up_block(filters, i, upsample_rate=up_size, skip=skip, **kwargs)(x)

    if classes < 2:
        activation = 'sigmoid'

    x = Conv2D(classes, (3,3), padding='same', name='final_conv')(x)
    x = Activation(activation, name=activation)(x)
    model = Model(input, x, name=name)

    return model

# %%
def UResNet34(input_shape=(None, None, 3), classes=1, decoder_filters=16, decoder_block_type='upsampling',
                       encoder_weights=None, input_tensor=None, activation='sigmoid', name='mymodel', **kwargs):

    backbone = ResnetBuilder.build_resnet_34(input_shape=input_shape)

    skip_connections = list([97,54,25])  # for resnet 34
    model = build_unet(backbone, classes, decoder_filters,
                       skip_connections, block_type=decoder_block_type,
                       activation=activation, name=name, **kwargs)
#     model.name = 'u-resnet34'

    return model

# %% [markdown]
# ## Build ResNet-Unet Model

# %%
from tensorflow.keras.layers import add, concatenate
import tf_slim as slim

# %%
model = UResNet34(input_shape=(128,128,3), name='u-resnet34-2')

# %%
model.summary()
# Out:
# Model: "u-resnet34-2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 64, 64, 64)   9472        input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 64, 64, 64)   256         conv2d_180[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 64, 64, 64)   0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_165[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 32, 32, 64)   36928       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 32, 32, 64)   256         conv2d_181[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 32, 32, 64)   0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 32, 32, 64)   36928       activation_166[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 32, 32, 64)   0           max_pooling2d_5[0][0]
#                                                                  conv2d_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 32, 32, 64)   256         add_80[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 32, 32, 64)   0           batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 32, 32, 64)   36928       activation_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 32, 32, 64)   256         conv2d_183[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 32, 32, 64)   0           batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 32, 32, 64)   36928       activation_168[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 32, 32, 64)   0           add_80[0][0]
#                                                                  conv2d_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 32, 32, 64)   256         add_81[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 32, 32, 64)   0           batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 32, 32, 64)   36928       activation_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 32, 32, 64)   256         conv2d_185[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 32, 32, 64)   0           batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 32, 32, 64)   36928       activation_170[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 32, 32, 64)   0           add_81[0][0]
#                                                                  conv2d_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 32, 32, 64)   256         add_82[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 32, 32, 64)   0           batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 16, 16, 128)  73856       activation_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 16, 16, 128)  512         conv2d_187[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 16, 16, 128)  0           batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 16, 16, 128)  8320        add_82[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 16, 16, 128)  147584      activation_172[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 16, 16, 128)  0           conv2d_189[0][0]
#                                                                  conv2d_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 16, 16, 128)  512         add_83[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 16, 16, 128)  0           batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 16, 16, 128)  147584      activation_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 16, 16, 128)  512         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 16, 16, 128)  0           batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 16, 16, 128)  147584      activation_174[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 16, 16, 128)  0           add_83[0][0]
#                                                                  conv2d_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 16, 16, 128)  512         add_84[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 16, 16, 128)  0           batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 16, 16, 128)  147584      activation_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 16, 16, 128)  512         conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 16, 16, 128)  0           batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 16, 16, 128)  147584      activation_176[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 16, 16, 128)  0           add_84[0][0]
#                                                                  conv2d_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 16, 16, 128)  512         add_85[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 16, 16, 128)  0           batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 16, 16, 128)  147584      activation_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 16, 16, 128)  512         conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 16, 16, 128)  0           batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 16, 16, 128)  147584      activation_178[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 16, 16, 128)  0           add_85[0][0]
#                                                                  conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 16, 16, 128)  512         add_86[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 16, 16, 128)  0           batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 8, 8, 256)    295168      activation_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 8, 8, 256)    1024        conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 8, 8, 256)    0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 8, 8, 256)    33024       add_86[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 8, 8, 256)    590080      activation_180[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 8, 8, 256)    0           conv2d_198[0][0]
#                                                                  conv2d_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 8, 8, 256)    1024        add_87[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 8, 8, 256)    0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 8, 8, 256)    590080      activation_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 8, 8, 256)    1024        conv2d_199[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 8, 8, 256)    0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 8, 8, 256)    590080      activation_182[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 8, 8, 256)    0           add_87[0][0]
#                                                                  conv2d_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 8, 8, 256)    1024        add_88[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 8, 8, 256)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 8, 8, 256)    590080      activation_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 8, 8, 256)    1024        conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 8, 8, 256)    0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 8, 8, 256)    590080      activation_184[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 8, 8, 256)    0           add_88[0][0]
#                                                                  conv2d_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 8, 8, 256)    1024        add_89[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 8, 8, 256)    0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 8, 8, 256)    590080      activation_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 8, 8, 256)    1024        conv2d_203[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 8, 8, 256)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 8, 8, 256)    590080      activation_186[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 8, 8, 256)    0           add_89[0][0]
#                                                                  conv2d_204[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 8, 8, 256)    1024        add_90[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 8, 8, 256)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 8, 8, 256)    590080      activation_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 8, 8, 256)    1024        conv2d_205[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 8, 8, 256)    0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 8, 8, 256)    590080      activation_188[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 8, 8, 256)    0           add_90[0][0]
#                                                                  conv2d_206[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 8, 8, 256)    1024        add_91[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 8, 8, 256)    0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 8, 8, 256)    590080      activation_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 8, 8, 256)    1024        conv2d_207[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 8, 8, 256)    0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 8, 8, 256)    590080      activation_190[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, 8, 8, 256)    0           add_91[0][0]
#                                                                  conv2d_208[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 8, 8, 256)    1024        add_92[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 8, 8, 256)    0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 4, 4, 512)    1180160     activation_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 4, 4, 512)    2048        conv2d_209[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 4, 4, 512)    0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 4, 4, 512)    131584      add_92[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 4, 4, 512)    2359808     activation_192[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 4, 4, 512)    0           conv2d_211[0][0]
#                                                                  conv2d_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 4, 4, 512)    2048        add_93[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 4, 4, 512)    0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 4, 4, 512)    2359808     activation_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 4, 4, 512)    2048        conv2d_212[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 4, 4, 512)    0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 4, 4, 512)    2359808     activation_194[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 4, 4, 512)    0           add_93[0][0]
#                                                                  conv2d_213[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 4, 4, 512)    2048        add_94[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 4, 4, 512)    0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 4, 4, 512)    2359808     activation_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 4, 4, 512)    2048        conv2d_214[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 4, 4, 512)    0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 4, 4, 512)    2359808     activation_196[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 4, 4, 512)    0           add_94[0][0]
#                                                                  conv2d_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 4, 4, 512)    2048        add_95[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 4, 4, 512)    0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsample (UpSamp (None, 8, 8, 512)    0           activation_197[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 8, 8, 768)    0           decoder_stage0_upsample[0][0]
#                                                                  activation_191[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv1 (Conv2D)   (None, 8, 8, 256)    1769728     concatenate_15[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu1 (Activatio (None, 8, 8, 256)    0           decoder_stage0_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv2 (Conv2D)   (None, 8, 8, 256)    590080      decoder_stage0_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu2 (Activatio (None, 8, 8, 256)    0           decoder_stage0_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsample (UpSamp (None, 16, 16, 256)  0           decoder_stage0_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 16, 16, 384)  0           decoder_stage1_upsample[0][0]
#                                                                  activation_179[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv1 (Conv2D)   (None, 16, 16, 128)  442496      concatenate_16[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu1 (Activatio (None, 16, 16, 128)  0           decoder_stage1_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv2 (Conv2D)   (None, 16, 16, 128)  147584      decoder_stage1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu2 (Activatio (None, 16, 16, 128)  0           decoder_stage1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsample (UpSamp (None, 32, 32, 128)  0           decoder_stage1_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 32, 32, 192)  0           decoder_stage2_upsample[0][0]
#                                                                  activation_171[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv1 (Conv2D)   (None, 32, 32, 64)   110656      concatenate_17[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu1 (Activatio (None, 32, 32, 64)   0           decoder_stage2_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv2 (Conv2D)   (None, 32, 32, 64)   36928       decoder_stage2_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu2 (Activatio (None, 32, 32, 64)   0           decoder_stage2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsample (UpSamp (None, 64, 64, 64)   0           decoder_stage2_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv1 (Conv2D)   (None, 64, 64, 32)   18464       decoder_stage3_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu1 (Activatio (None, 64, 64, 32)   0           decoder_stage3_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv2 (Conv2D)   (None, 64, 64, 32)   9248        decoder_stage3_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu2 (Activatio (None, 64, 64, 32)   0           decoder_stage3_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsample (UpSamp (None, 128, 128, 32) 0           decoder_stage3_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv1 (Conv2D)   (None, 128, 128, 16) 4624        decoder_stage4_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu1 (Activatio (None, 128, 128, 16) 0           decoder_stage4_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv2 (Conv2D)   (None, 128, 128, 16) 2320        decoder_stage4_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu2 (Activatio (None, 128, 128, 16) 0           decoder_stage4_conv2[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 128, 128, 1)  145         decoder_stage4_relu2[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 128, 128, 1)  0           final_conv[0][0]
# ==================================================================================================
# Total params: 24,438,897
# Trainable params: 24,423,665
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True, to_file='resnet35-unet-ssim-loss.png')

# %%
def SSIM(y, x):
#     print(tf.size(y))
#     print(y[:,2])
    print(x.shape)
#     print(x.shape[0])
#     if x.shape[0] == None:
#         return 0
    C1 = 0.01 ** 2
    C2 = 0.03 ** 2
#     y_actual = tf.reshape(y, [y.shape[0], y.shape[1], y.shape[2], 1])
#     y_pred = tf.reshape(x, [x.shape[0], x.shape[1], x.shape[2], 1])
    mu_x = tf.nn.avg_pool(x, 3, 1, 'VALID')
    mu_y = tf.nn.avg_pool(y, 3, 1, 'VALID')

    sigma_x  = tf.nn.avg_pool(x ** 2, 3, 1, 'VALID') - mu_x ** 2
    sigma_y  = tf.nn.avg_pool(y ** 2, 3, 1, 'VALID') - mu_y ** 2
    sigma_xy = tf.nn.avg_pool(x * y , 3, 1, 'VALID') - mu_x * mu_y

    SSIM_n = (2 * mu_x * mu_y + C1) * (2 * sigma_xy + C2)
    SSIM_d = (mu_x ** 2 + mu_y ** 2 + C1) * (sigma_x + sigma_y + C2)

    SSIM = SSIM_n / SSIM_d
    print('SSIM calculated {}'.format(tf.clip_by_value((1 - SSIM) / 2, 0, 1)))
    return tf.clip_by_value((1 - SSIM) / 2, 0, 1)

# %%
model.compile(optimizer='adam', loss=SSIM, metrics=['acc', SSIM])

# %%
# finish this later on...
import tensorflow.keras as keras
class DataGenerator(keras.utils.Sequence):
  
  def __init__(self, batch_size = 8, image_size = 128):
    self.batch_size = batch_size
    self.image_size = image_size
    
  def load(self, rgb_file, depth_file):
    image = cv2.imread(rgb_file)
    image = cv2.resize(image, (self.image_size, self.image_size)) # resize...
    depth = cv2.imread(depth_file, -1)
    depth = cv2.resize(depth, (self.image_size, self.image_size)) 

    image_normalized = image/np.max(image)
    depth_normalized = depth/np.max(depth) # double check the depth images!
    return image_normalized, depth_normalized

  def load_all(self, rgb_files, depth_files):
        images = []
        depths = []
        for i in range(len(rgb_files)):
            img, dpth = self.load(rgb_files[i], depth_files[i])
            images.append(img)
            depths.append(dpth)
        return np.array(images), np.array(depths)

# %%
# Get file names
rgb_images = os.listdir('train-data/rgb/')
rgb_images.sort()
rgb_images = [str('train-data/rgb/') + file for file in rgb_images]
depth_images = os.listdir('train-data/depth/')
depth_images.sort()
depth_images = [str('train-data/depth/') + file for file in depth_images]

test_size = 480
rgb_images_test = rgb_images[:test_size]
depth_images_test = depth_images[:test_size]

rgb_images_train = rgb_images[test_size:]
depth_images_train = depth_images[test_size:]

# Load data:

load_data = DataGenerator()

X_train, y_train = load_data.load_all(rgb_files=rgb_images_train, 
                                      depth_files=depth_images_train)

X_test, y_test = load_data.load_all(rgb_files=rgb_images_test, 
                                  depth_files=depth_images_test)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1129, 128, 128, 3) (1129, 128, 128)
# (480, 128, 128, 3) (480, 128, 128)

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "2"

# %%
model.fit(X_train, y_train, batch_size=8, epochs=50, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# (None, 128, 128)
# SSIM calculated Tensor("SSIM/clip_by_value:0", shape=(None, 126, 128), dtype=float32)
# (None, 128, 128)
# SSIM calculated Tensor("clip_by_value:0", shape=(None, 126, 128), dtype=float32)
# (None, 128, 128)
# SSIM calculated Tensor("SSIM/clip_by_value:0", shape=(None, 126, 128), dtype=float32)
# (None, 128, 128)
# SSIM calculated Tensor("clip_by_value:0", shape=(None, 126, 128), dtype=float32)
# 113/113 [==============================] - ETA: 0s - loss: 0.2178 - acc: 0.1019 - SSIM: 0.2165(None, 128, 128)
# SSIM calculated Tensor("SSIM/clip_by_value:0", shape=(None, 126, 128), dtype=float32)
# (None, 128, 128)
# SSIM calculated Tensor("clip_by_value:0", shape=(None, 126, 128), dtype=float32)
# 113/113 [==============================] - 9s 41ms/step - loss: 0.2178 - acc: 0.1018 - SSIM: 0.2164 - val_loss: 0.2415 - val_acc: 0.1325 - val_SSIM: 0.2386
# Epoch 2/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.2177 - acc: 0.1212 - SSIM: 0.2118 - val_loss: 0.2122 - val_acc: 0.1867 - val_SSIM: 0.2083
# Epoch 3/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.2011 - acc: 0.1817 - SSIM: 0.1966 - val_loss: 0.1792 - val_acc: 0.2346 - val_SSIM: 0.1690
# Epoch 4/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1735 - acc: 0.1987 - SSIM: 0.1672 - val_loss: 0.1760 - val_acc: 0.1634 - val_SSIM: 0.1724
# Epoch 5/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1698 - acc: 0.1909 - SSIM: 0.1661 - val_loss: 0.1694 - val_acc: 0.2080 - val_SSIM: 0.1661
# Epoch 6/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1466 - acc: 0.2266 - SSIM: 0.1406 - val_loss: 0.1163 - val_acc: 0.2247 - val_SSIM: 0.1116
# Epoch 7/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1176 - acc: 0.2320 - SSIM: 0.1127 - val_loss: 0.1099 - val_acc: 0.2281 - val_SSIM: 0.1067
# Epoch 8/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1156 - acc: 0.2339 - SSIM: 0.1120 - val_loss: 0.1179 - val_acc: 0.2238 - val_SSIM: 0.1143
# Epoch 9/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1156 - acc: 0.2344 - SSIM: 0.1117 - val_loss: 0.1112 - val_acc: 0.2276 - val_SSIM: 0.1078
# Epoch 10/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1173 - acc: 0.2338 - SSIM: 0.1141 - val_loss: 0.1216 - val_acc: 0.2222 - val_SSIM: 0.1194
# Epoch 11/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1125 - acc: 0.2327 - SSIM: 0.1100 - val_loss: 0.1142 - val_acc: 0.2268 - val_SSIM: 0.1104
# Epoch 12/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1171 - acc: 0.2354 - SSIM: 0.1132 - val_loss: 0.1152 - val_acc: 0.2328 - val_SSIM: 0.1109
# Epoch 13/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1145 - acc: 0.2331 - SSIM: 0.1110 - val_loss: 0.1118 - val_acc: 0.2327 - val_SSIM: 0.1097
# Epoch 14/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1137 - acc: 0.2337 - SSIM: 0.1110 - val_loss: 0.1243 - val_acc: 0.2212 - val_SSIM: 0.1215
# Epoch 15/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1147 - acc: 0.2334 - SSIM: 0.1097 - val_loss: 0.1097 - val_acc: 0.2265 - val_SSIM: 0.1069
# Epoch 16/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1137 - acc: 0.2338 - SSIM: 0.1107 - val_loss: 0.1122 - val_acc: 0.2346 - val_SSIM: 0.1094
# Epoch 17/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1134 - acc: 0.2340 - SSIM: 0.1101 - val_loss: 0.1134 - val_acc: 0.2350 - val_SSIM: 0.1106
# Epoch 18/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1141 - acc: 0.2350 - SSIM: 0.1113 - val_loss: 0.1118 - val_acc: 0.2370 - val_SSIM: 0.1093
# Epoch 19/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1133 - acc: 0.2334 - SSIM: 0.1102 - val_loss: 0.1109 - val_acc: 0.2346 - val_SSIM: 0.1082
# Epoch 20/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1120 - acc: 0.2336 - SSIM: 0.1088 - val_loss: 0.1136 - val_acc: 0.2327 - val_SSIM: 0.1096
# Epoch 21/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1129 - acc: 0.2329 - SSIM: 0.1092 - val_loss: 0.1137 - val_acc: 0.2256 - val_SSIM: 0.1103
# Epoch 22/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1125 - acc: 0.2340 - SSIM: 0.1090 - val_loss: 0.1157 - val_acc: 0.2379 - val_SSIM: 0.1104
# Epoch 23/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1130 - acc: 0.2337 - SSIM: 0.1094 - val_loss: 0.1117 - val_acc: 0.2318 - val_SSIM: 0.1085
# Epoch 24/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1122 - acc: 0.2344 - SSIM: 0.1093 - val_loss: 0.1501 - val_acc: 0.2235 - val_SSIM: 0.1398
# Epoch 25/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1148 - acc: 0.2346 - SSIM: 0.1102 - val_loss: 0.1126 - val_acc: 0.2305 - val_SSIM: 0.1092
# Epoch 26/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1143 - acc: 0.2338 - SSIM: 0.1107 - val_loss: 0.1101 - val_acc: 0.2318 - val_SSIM: 0.1074
# Epoch 27/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1129 - acc: 0.2349 - SSIM: 0.1099 - val_loss: 0.1113 - val_acc: 0.2384 - val_SSIM: 0.1086
# Epoch 28/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1119 - acc: 0.2357 - SSIM: 0.1089 - val_loss: 0.1101 - val_acc: 0.2316 - val_SSIM: 0.1074
# Epoch 29/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1110 - acc: 0.2337 - SSIM: 0.1081 - val_loss: 0.1115 - val_acc: 0.2342 - val_SSIM: 0.1087
# Epoch 30/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1121 - acc: 0.2349 - SSIM: 0.1087 - val_loss: 0.1192 - val_acc: 0.2225 - val_SSIM: 0.1138
# Epoch 31/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1135 - acc: 0.2338 - SSIM: 0.1099 - val_loss: 0.1129 - val_acc: 0.2394 - val_SSIM: 0.1100
# Epoch 32/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1117 - acc: 0.2354 - SSIM: 0.1085 - val_loss: 0.1109 - val_acc: 0.2276 - val_SSIM: 0.1079
# Epoch 33/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1114 - acc: 0.2342 - SSIM: 0.1083 - val_loss: 0.1116 - val_acc: 0.2364 - val_SSIM: 0.1088
# Epoch 34/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1126 - acc: 0.2360 - SSIM: 0.1092 - val_loss: 0.1135 - val_acc: 0.2345 - val_SSIM: 0.1105
# Epoch 35/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1105 - acc: 0.2340 - SSIM: 0.1071 - val_loss: 0.1105 - val_acc: 0.2271 - val_SSIM: 0.1078
# Epoch 36/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1117 - acc: 0.2351 - SSIM: 0.1088 - val_loss: 0.1129 - val_acc: 0.2305 - val_SSIM: 0.1085
# Epoch 37/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1091 - acc: 0.2346 - SSIM: 0.1058 - val_loss: 0.1126 - val_acc: 0.2343 - val_SSIM: 0.1098
# Epoch 38/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1117 - acc: 0.2354 - SSIM: 0.1087 - val_loss: 0.1158 - val_acc: 0.2243 - val_SSIM: 0.1116
# Epoch 39/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1118 - acc: 0.2350 - SSIM: 0.1081 - val_loss: 0.1129 - val_acc: 0.2348 - val_SSIM: 0.1093
# Epoch 40/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1098 - acc: 0.2347 - SSIM: 0.1066 - val_loss: 0.1110 - val_acc: 0.2360 - val_SSIM: 0.1084
# Epoch 41/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1116 - acc: 0.2356 - SSIM: 0.1083 - val_loss: 0.1142 - val_acc: 0.2399 - val_SSIM: 0.1111
# Epoch 42/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1081 - acc: 0.2332 - SSIM: 0.1048 - val_loss: 0.1141 - val_acc: 0.2291 - val_SSIM: 0.1111
# Epoch 43/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1093 - acc: 0.2343 - SSIM: 0.1060 - val_loss: 0.1137 - val_acc: 0.2286 - val_SSIM: 0.1107
# Epoch 44/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1087 - acc: 0.2334 - SSIM: 0.1056 - val_loss: 0.1108 - val_acc: 0.2330 - val_SSIM: 0.1081
# Epoch 45/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1075 - acc: 0.2335 - SSIM: 0.1043 - val_loss: 0.1153 - val_acc: 0.2330 - val_SSIM: 0.1109
# Epoch 46/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1103 - acc: 0.2335 - SSIM: 0.1071 - val_loss: 0.1140 - val_acc: 0.2314 - val_SSIM: 0.1106
# Epoch 47/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1071 - acc: 0.2327 - SSIM: 0.1038 - val_loss: 0.1121 - val_acc: 0.2308 - val_SSIM: 0.1090
# Epoch 48/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1104 - acc: 0.2358 - SSIM: 0.1071 - val_loss: 0.1149 - val_acc: 0.2293 - val_SSIM: 0.1108
# Epoch 49/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1097 - acc: 0.2349 - SSIM: 0.1063 - val_loss: 0.1138 - val_acc: 0.2347 - val_SSIM: 0.1106
# Epoch 50/50
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1079 - acc: 0.2336 - SSIM: 0.1044 - val_loss: 0.1163 - val_acc: 0.2326 - val_SSIM: 0.1132

# %%
preds = model.predict(X_test)

# %%
prds1 = np.reshape(preds[0], newshape=(preds[0].shape[0]*preds[0].shape[1]))
plt.subplot(2,1,1)
plt.imshow(np.reshape(prds1, newshape=(128, 128))*255)
plt.subplot(2,1,2)
plt.imshow(y_test[0]*255)
